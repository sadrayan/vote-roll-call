# %%
import pandas as pd
import numpy as np

import random
import string
from tqdm import tqdm

import gensim
from gensim import utils

from keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
  

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
sns.set(style='whitegrid', palette='muted', font_scale=1.2)

tqdm.pandas(desc='progress-bar')
# Out:
# Using TensorFlow backend.

# %%
df_bills = pd.read_csv('data/bill_all.csv')
print(df_bills.columns)
df_bills.tail()
# Out:
# Index(['Unnamed: 0', 'index', 'Unnamed: 0.1', 'action_date', 'action_time',
#        'chamber', 'congress', 'legis_num', 'majority', 'name', 'party', 'role',
#        'rollcall_num', 'session', 'state', 'vote', 'vote_desc',
#        'vote_question', 'vote_result', 'vote_type', 'link', 'billText',
#        'bill_url', 'sponsor', 'sponsor_id', 'sponsor_party', 'sponsor_state',
#        'sponsor_uri'],
#       dtype='object')
#       Unnamed: 0    index  Unnamed: 0.1  action_date action_time  \
# 4057        4057  5158792       5158792  13-Dec-2011     6:59 PM
# 4058        4058  5160455       5160455  14-Dec-2011     6:17 PM
# 4059        4059  5161291       5161291  14-Dec-2011     6:31 PM
# 4060        4060  5165452       5165452  16-Dec-2011    11:54 AM
# 4061        4061  5166702       5166702  16-Dec-2011     2:04 PM
#
#                             chamber  congress legis_num majority      name  \
# 4057  U.S. House of Representatives       112  H R 2767        R  Ackerman
# 4058  U.S. House of Representatives       112  H R 2105        R  Ackerman
# 4059  U.S. House of Representatives       112  H R 1264        R  Ackerman
# 4060  U.S. House of Representatives       112     S 278        R  Ackerman
# 4061  U.S. House of Representatives       112  H R 3672        R  Ackerman
#
#                             ...                         vote_result  \
# 4057                        ...                              Passed
# 4058                        ...                              Passed
# 4059                        ...                              Passed
# 4060                        ...                              Passed
# 4061                        ...                              Passed
#
#               vote_type                                               link  \
# 4057  2/3 RECORDED VOTE  https://www.congress.gov/bill/112th-congress/h...
# 4058    2/3 YEA-AND-NAY  https://www.congress.gov/bill/112th-congress/h...
# 4059    2/3 YEA-AND-NAY  https://www.congress.gov/bill/112th-congress/h...
# 4060  2/3 RECORDED VOTE  https://www.congress.gov/bill/112th-congress/h...
# 4061        YEA-AND-NAY  https://www.congress.gov/bill/112th-congress/h...
#
#                                                billText  \
# 4057  112th congress public law u.s government print...
# 4058  congressional bills 112th congress u.s governm...
# 4059  112th congress public law u.s government print...
# 4060  congressional bills 112th congress u.s governm...
# 4061  112th congress public law u.s government print...
#
#                                                bill_url           sponsor  \
# 4057  https://api.propublica.org/congress/v1/112/bil...  Gary L. Ackerman
# 4058  https://api.propublica.org/congress/v1/112/bil...  Gary L. Ackerman
# 4059  https://api.propublica.org/congress/v1/112/bil...  Gary L. Ackerman
# 4060  https://api.propublica.org/congress/v1/112/bil...  Gary L. Ackerman
# 4061  https://api.propublica.org/congress/v1/112/bil...  Gary L. Ackerman
#
#      sponsor_id sponsor_party sponsor_state  \
# 4057    A000022             D            NY
# 4058    A000022             D            NY
# 4059    A000022             D            NY
# 4060    A000022             D            NY
# 4061    A000022             D            NY
#
#                                             sponsor_uri
# 4057  https://api.propublica.org/congress/v1/members...
# 4058  https://api.propublica.org/congress/v1/members...
# 4059  https://api.propublica.org/congress/v1/members...
# 4060  https://api.propublica.org/congress/v1/members...
# 4061  https://api.propublica.org/congress/v1/members...
#
# [5 rows x 28 columns]

# %%
df_votes = pd.read_csv('data/votes_all.csv')
print(df_votes.columns)
df_votes.tail()
# Out:
# Index(['Unnamed: 0', 'action_date', 'action_time', 'chamber', 'congress',
#        'legis_num', 'majority', 'name', 'party', 'role', 'rollcall_num',
#        'session', 'state', 'vote', 'vote_desc', 'vote_question', 'vote_result',
#        'vote_type'],
#       dtype='object')
#          Unnamed: 0  action_date action_time                        chamber  \
# 5169626     5169626  20-Dec-2011     4:16 PM  U.S. House of Representatives
# 5169627     5169627  20-Dec-2011     4:16 PM  U.S. House of Representatives
# 5169628     5169628  20-Dec-2011     4:16 PM  U.S. House of Representatives
# 5169629     5169629  20-Dec-2011     4:16 PM  U.S. House of Representatives
# 5169630     5169630  20-Dec-2011     4:16 PM  U.S. House of Representatives
#
#          congress  legis_num majority        name party        role  \
# 5169626       112  H RES 501        R     Woodall     R  legislator
# 5169627       112  H RES 501        R       Yoder     R  legislator
# 5169628       112  H RES 501        R  Young (AK)     R  legislator
# 5169629       112  H RES 501        R  Young (FL)     R  legislator
# 5169630       112  H RES 501        R  Young (IN)     R  legislator
#
#          rollcall_num session state vote  \
# 5169626           949     1st    GA  Yea
# 5169627           949     1st    KS  Yea
# 5169628           949     1st    AK  Yea
# 5169629           949     1st    FL  Yea
# 5169630           949     1st    IN  Yea
#
#                                                  vote_desc  \
# 5169626  Expressing the sense of the House of Represent...
# 5169627  Expressing the sense of the House of Represent...
# 5169628  Expressing the sense of the House of Represent...
# 5169629  Expressing the sense of the House of Represent...
# 5169630  Expressing the sense of the House of Represent...
#
#                          vote_question vote_result    vote_type
# 5169626  On Agreeing to the Resolution      Passed  YEA-AND-NAY
# 5169627  On Agreeing to the Resolution      Passed  YEA-AND-NAY
# 5169628  On Agreeing to the Resolution      Passed  YEA-AND-NAY
# 5169629  On Agreeing to the Resolution      Passed  YEA-AND-NAY
# 5169630  On Agreeing to the Resolution      Passed  YEA-AND-NAY

# %%
print((df_bills['congress'].value_counts()))
df_bills['congress'].value_counts().plot(kind='bar', alpha=.5)
# Out:
# 110    879
# 111    672
# 108    414
# 109    364
# 107    354
# 114    346
# 113    324
# 112    286
# 115    256
# 106    167
# Name: congress, dtype: int64

# %%
print((df_votes['vote'].value_counts()))
df_votes['vote'].value_counts().plot(kind='bar', alpha=.5)
# Out:
# Yea    3335561
# Nay    1834070
# Name: vote, dtype: int64

# %%
print((df_votes['vote_result'].value_counts()))
df_votes['vote_result'].value_counts().plot(kind='bar', alpha=.5)
# Out:
# Passed       2980219
# Failed       1657896
# Agreed to     531516
# Name: vote_result, dtype: int64

# %% [markdown]
# # Creat Vote Matrix and Bill representation

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('/home/sonic/.keras/datasets/GoogleNews-vectors-negative300.bin',
                                                        binary=True)

# %%
  
max_words = 20000
MAX_SEQUENCE_LENGTH = 10000
def process_doc(X):
    tokenizer = Tokenizer(num_words=max_words,lower=True, split=' ', 
                          filters='"#%&()*+-/<=>@[\\]^_`{|}~\t\n',
                          char_level=False, oov_token=u'<UNK>')

    tokenizer.fit_on_texts(X)

    X_seq = tokenizer.texts_to_sequences(X)

    count_vect = CountVectorizer()
    X_train_counts = count_vect.fit_transform(X)

    tf_transformer = TfidfTransformer().fit(X_train_counts)
    X_train_tf = tf_transformer.transform(X_train_counts)

    x_emb =[]
    for doc in X: #look up each doc in model
        x_emb.append(document_vector(model, doc))


    word_index = tokenizer.word_index
    print('Found %s unique tokens.' % len(word_index))

#     X = pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH,  padding="post", truncating="post")
    return np.array(X_seq), word_index, np.array(x_emb), X_train_tf, X_train_counts

def document_vector(word2vec_model, doc):
    # remove out-of-vocabulary words
    doc = [word for word in doc if word in word2vec_model.vocab]
    return np.mean(word2vec_model[doc], axis=0)


def has_vector_representation(word2vec_model, doc):
    """check if at least one word of the document is in the
    word2vec dictionary"""
    return not all(word not in word2vec_model.vocab for word in doc)

# %%
# %%time


AYE = 1
NAY = -1

vote_matrix_all = {}
X_seq_all = {}
word_index_all = {}
X_train_tf_all = {}
X_train_counts_all = {}
X_emb_all = {}
legistlator_dict_all = {}


grouped_congress = df_bills.groupby('congress')

feature_all = {}
y_all = {}


for name, group in grouped_congress:
    print('Processing congress', name)
    print('congress shape', group.shape)
    
    df_votes_filtered = df_votes[df_votes['congress'] == name]
    
    num_legistlators = len(df_votes_filtered['name'].unique())
    print('number of legistlators', num_legistlators)
    vote_matrix = np.zeros((group.shape[0], num_legistlators))
    print('vote_matrix.shape', vote_matrix.shape)
    
    # Creat legistor dict mapping!
    legistlator_dict = {}
    i = 0
    for legitslator in df_votes_filtered['name'].unique():
        legistlator_dict[legitslator] = i
        i += 1
    
    legistlator_dict_all[name] = {v: k for k, v in legistlator_dict.items()} 
    
    ########
#     majority, party, vote
#     print(pd.get_dummies(df_votes_filtered['majority']).shape)
#     print(pd.get_dummies(df_votes_filtered['party']).shape)
#     feature_all[name] = np.hstack((pd.get_dummies(df_votes_filtered['majority']), 
#                                   pd.get_dummies(df_votes_filtered['party'])))
#     print(preprocessing.OneHotEncoder().fit_transform(df_votes_filtered['majority']))
    
    
#     print((df_votes_filtered['vote'].value_counts()))

#     y_all[name] = df_votes_filtered['vote']
    ########
        
#     print(legistlator_dict)
    print('Processing congress votes')
    group.reset_index(inplace=True)
    
    vote_feature = []
    # Process Vote matrix here
    for index, row in tqdm(group.iterrows()):
        
        df_filtered = df_votes_filtered[df_votes_filtered['legis_num'] == row['legis_num']]

        for _, vote in df_filtered.iterrows():
            vote_feature.append({'majority' : vote['majority'], 
                         'party' : vote['party'],
                         'sponser' : row['sponsor_party'],
                         'y' :  vote['vote']})
            if vote['vote'] == 'Yea':
                vote_matrix[index, legistlator_dict[vote['name']]] = AYE
            elif vote['vote'] == 'Nay':
                vote_matrix[index, legistlator_dict[vote['name']]] = NAY

    # Process bill Representation Here
    print('processing congress bills')
    X_seq, word_index, x_emb, X_train_tf, X_train_counts = process_doc(group['billText'].apply(str))

    feature_all[name] = vote_feature
    vote_matrix_all[name] = vote_matrix
    X_seq_all[name] = X_seq
    word_index_all[name] = word_index
    X_emb_all[name] = x_emb
    X_train_tf_all[name] = X_train_tf
    X_train_counts_all[name] = X_train_counts
    
    print('*' * 50)
    break
    
# print('feature_all', feature_all[106].shape)
# print('y_all', y_all[106].shape)
    
print('vote_matrix_all.shape', vote_matrix_all[106].shape)
np.save('data/vote_matrix_all.npy', vote_matrix_all)
np.save('data/X_seq_all.npy', X_seq_all)
np.save('data/X_word_index_all.npy', word_index_all)
np.save('data/X_train_tf_all.npy', X_train_tf_all)
np.save('data/X_train_counts_all.npy', X_train_counts_all)
np.save('data/X_emb_all.npy', X_emb_all)
np.save('data/legistlator_all.npy', legistlator_dict_all)
# Out:
# 3it [00:00, 23.24it/s]
# Processing congress 106
# congress shape (167, 28)
# number of legistlators 435
# vote_matrix.shape (167, 435)
# Processing congress votes
# 80it [00:06, 11.53it/s]

# %%
# print(feature_all[106].shape)
df_train = pd.DataFrame(feature_all[106])
df_train.tail()

# %%
# %%time


# PARTY LINE EXPERIMENTS:

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn import preprocessing
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis


encoder = preprocessing.LabelEncoder()

print(encoder.fit_transform(df_train['majority']).shape)
X = np.hstack((encoder.fit_transform(df_train['majority']), 
               encoder.fit_transform(df_train['party']), 
               encoder.fit_transform(df_train['sponser'])))

# print(X)
y = df_train['y'].tolist()
le = preprocessing.LabelEncoder()
le.fit(y)
print(le.classes_)
y = le.transform(y)
print(X[:10])
print(y[:10])

print(X.shape)
print(y.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

print('X_train', X_train.shape)
print('y_train', y_train.shape)


# classifiers = [
#     KNeighborsClassifier(3),
#     SVC(kernel="linear", C=0.025),
#     SVC(gamma=2, C=1),
#     GaussianProcessClassifier(1.0 * RBF(1.0)),
#     DecisionTreeClassifier(max_depth=5),
#     RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
#     MLPClassifier(alpha=1),
#     AdaBoostClassifier(),
#     GaussianNB(),
#     QuadraticDiscriminantAnalysis()]


# clf = SVC(kernel="linear", C=0.025)
# clf = LinearRegression()
clf = MLPClassifier(alpha=1)
# clf = AdaBoostClassifier()
clf.fit(X_train, y_train)

y_predict = clf.predict(X_test)
print('score', clf.score(X_test, y_predict))

regression_model_mse = mean_squared_error(y_test, y_predict)
print('accuracy', accuracy_score(y_test, y_predict))

print('model_mse', regression_model_mse)

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict, target_names=le.classes_))

# %%
print(vote_matrix_all[106].shape)
print(X_seq_all[106].shape)
# print(word_index_all[106].shape)
print(X_train_tf_all[106].shape)
print(X_train_counts_all[106].shape)
print(X_emb_all[106].shape)

# %%
congress = 115
x = X_emb_all[congress]
print('x', x.shape)
df_congress = df_bills[df_bills['congress'] == congress]
y = df_congress['party'].values
print(y.shape)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(y)
print(le.classes_)
y = le.transform(y)
print(y)

colors = ['blue', 'red']

# %%
# Pretty Useless :) 
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x)

plt.figure(1, figsize=(20, 20),)
plt.scatter(x_pca[:, 0], x_pca[:, 1], s=100, c=y, cmap=matplotlib.colors.ListedColormap(colors), alpha=0.6)

# %%
from sklearn.manifold import TSNE
X_tsne = TSNE(n_components=2, verbose=2).fit_transform(x)

plt.figure(1, figsize=(20, 20),)
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], s=100, c=y, cmap=matplotlib.colors.ListedColormap(colors), alpha=0.6)
