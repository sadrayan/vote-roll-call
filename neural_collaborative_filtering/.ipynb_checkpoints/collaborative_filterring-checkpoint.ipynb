# %%
import keras
from IPython.display import SVG
from keras.optimizers import Adam
from keras.utils.vis_utils import model_to_dot

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %matplotlib inline
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
# Out:
# Using TensorFlow backend.

# %%
df_final = pd.read_csv('../data/df_vote_final.csv')
df_final.tail()
# Out:
#          Unnamed: 0  level_0    index  Unnamed: 0.1  action_date action_time  \
# 5103690     5103690      413  2835512       2835512  19-Mar-2015    12:08 PM
# 5103691     5103691      414  2835513       2835513  19-Mar-2015    12:08 PM
# 5103692     5103692      415  2835514       2835514  19-Mar-2015    12:08 PM
# 5103693     5103693      416  2835515       2835515  19-Mar-2015    12:08 PM
# 5103694     5103694      417  2835516       2835516  19-Mar-2015    12:08 PM
#
#                                chamber  congress  legis_num majority  \
# 5103690  U.S. House of Representatives       114  S J RES 8        R
# 5103691  U.S. House of Representatives       114  S J RES 8        R
# 5103692  U.S. House of Representatives       114  S J RES 8        R
# 5103693  U.S. House of Representatives       114  S J RES 8        R
# 5103694  U.S. House of Representatives       114  S J RES 8        R
#
#                                ...                         vote  \
# 5103690                        ...                          Yea
# 5103691                        ...                          Yea
# 5103692                        ...                          Yea
# 5103693                        ...                          Yea
# 5103694                        ...                          Yea
#
#                                                  vote_desc vote_question  \
# 5103690  Providing for congressional disapproval under ...    On Passage
# 5103691  Providing for congressional disapproval under ...    On Passage
# 5103692  Providing for congressional disapproval under ...    On Passage
# 5103693  Providing for congressional disapproval under ...    On Passage
# 5103694  Providing for congressional disapproval under ...    On Passage
#
#          vote_result    vote_type          sponsor sponsor_id sponsor_party  \
# 5103690       Passed  YEA-AND-NAY  Lamar Alexander    A000360             R
# 5103691       Passed  YEA-AND-NAY  Lamar Alexander    A000360             R
# 5103692       Passed  YEA-AND-NAY  Lamar Alexander    A000360             R
# 5103693       Passed  YEA-AND-NAY  Lamar Alexander    A000360             R
# 5103694       Passed  YEA-AND-NAY  Lamar Alexander    A000360             R
#
#         sponsor_state                                        sponsor_uri
# 5103690            TN  https://api.propublica.org/congress/v1/members...
# 5103691            TN  https://api.propublica.org/congress/v1/members...
# 5103692            TN  https://api.propublica.org/congress/v1/members...
# 5103693            TN  https://api.propublica.org/congress/v1/members...
# 5103694            TN  https://api.propublica.org/congress/v1/members...
#
# [5 rows x 26 columns]

# %%
df_final.columns
# Out:
# Index(['Unnamed: 0', 'level_0', 'index', 'Unnamed: 0.1', 'action_date',
#        'action_time', 'chamber', 'congress', 'legis_num', 'majority', 'name',
#        'party', 'role', 'rollcall_num', 'session', 'state', 'vote',
#        'vote_desc', 'vote_question', 'vote_result', 'vote_type', 'sponsor',
#        'sponsor_id', 'sponsor_party', 'sponsor_state', 'sponsor_uri'],
#       dtype='object')

# %%
dataset = df_final[['name', 'party', 'legis_num', 'vote']]
dataset['bill_id'] = dataset.legis_num.astype('category').cat.codes.values
dataset['name_id'] = dataset.name.astype('category').cat.codes.values
dataset['vote'] = dataset.vote.astype('category').cat.codes.values

# dataset.drop(columns=['name', 'legis_num'], inplace=True)
dataset = dataset.sample(frac=0.2, replace=True)
dataset.reset_index(inplace=True)
dataset.tail()
# Out:
#            index          name party      legis_num  vote  bill_id  name_id
# 1020734  4225153   Larsen (WA)     D      H RES 447     1     3279      607
# 1020735  4143410        McKeon     R      H RES 382     1     3216      696
# 1020736  3126185  Garrett (NJ)     R       H R 5501     0     2209      377
# 1020737  3950389        Saxton     R      H RES 228     1     3064      916
# 1020738   131709       Hinchey     D  H CON RES 397     1      194      475

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(dataset, test_size=0.2)

print()
print('train',train.shape)
print('test', test.shape)
train.head()
# Out:
# train (816591, 7)
# test (204148, 7)
#           index        name party  legis_num  vote  bill_id  name_id
# 184778   876532    LoBiondo     R   H R 2016     0      811      629
# 152229  1159211    Sarbanes     D   H R 2397     1      959      914
# 263190  4804565      Hunter     R  H RES 951     1     3747      502
# 513166  1390547      Watson     D   H R 2641     0     1059     1069
# 560802  1038444  Smith (NE)     R   H R 2219     1      889      966

# %%
n_users, n_bill = len(dataset.name_id.unique()), len(dataset.bill_id.unique())
n_latent_factors = 50

print('number of legsitlators:', n_users)
print('number of bills', n_bill)
print('TRAIN #number legitlators:', len(train.name_id.unique()), '#bills:', len(train.bill_id.unique()),)
print('TEST #number legitlators:', len(test.name_id.unique()), '#bills:', len(test.bill_id.unique()),)
# Out:
# number of legsitlators: 1117
# number of bills 4061
# TRAIN #number legitlators: 1116 #bills: 4061
# TEST #number legitlators: 1116 #bills: 4061

# %%
def plot_history(history):
    print(history.history)
    df = pd.DataFrame(history.history)
    print(df.describe())
    df.plot(xticks=range(epochs))
#     print(history.history.keys())

# %%
! cd /home/sonic/.keras/datasets/glove.6B.100d.txt
# Out:
# /bin/sh: line 0: cd: /home/sonic/.keras/datasets/glove.6B.100d.txt: Not a directory

# %%
def get_matrix_factorisation():
    movie_input = keras.layers.Input(shape=[1],name='Item')
    movie_embedding = keras.layers.Embedding(n_bill + 1, n_latent_factors, name='Movie-Embedding')(movie_input)
    movie_vec = keras.layers.Flatten(name='FlattenMovies')(movie_embedding)

    user_input = keras.layers.Input(shape=[1],name='User')
    user_vec = keras.layers.Flatten(name='FlattenUsers')(keras.layers.Embedding(n_users + 1, 
                                                                                n_latent_factors,
                                                                                name='User-Embedding')(user_input))

    prod = keras.layers.dot([movie_vec, user_vec], axes=1, name='DotProduct')
    model = keras.Model([user_input, movie_input], prod)
    model.compile('adam', 'mean_squared_error')
    # SVG(model_to_dot(model,  show_shapes=True, show_layer_names=True, rankdir='HB').create(prog='dot', format='svg'))
    return model

# %%
# load the whole embedding into memory
embeddings_index = dict()
f = open('/home/sonic/.keras/datasets/glove.6B.100d.txt')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %% [markdown]
# # Matrix Factorisation

# %%
def get_matrix_factorisation():
    movie_input = keras.layers.Input(shape=[1],name='Item')
    movie_embedding = keras.layers.Embedding(n_bill + 1, n_latent_factors, name='Movie-Embedding')(movie_input)
    movie_vec = keras.layers.Flatten(name='FlattenMovies')(movie_embedding)

    user_input = keras.layers.Input(shape=[1],name='User')
    user_vec = keras.layers.Flatten(name='FlattenUsers')(keras.layers.Embedding(n_users + 1, 
                                                                                n_latent_factors,
                                                                                name='User-Embedding')(user_input))

    prod = keras.layers.dot([movie_vec, user_vec], axes=1, name='DotProduct')
    model = keras.Model([user_input, movie_input], prod)
    model.compile('adam', 'mean_squared_error')
    # SVG(model_to_dot(model,  show_shapes=True, show_layer_names=True, rankdir='HB').create(prog='dot', format='svg'))
    return model

# %%
epochs=2

model = get_matrix_factorisation()
model.summary()

history = model.fit([train.name_id, train.bill_id], 
                    train.vote, epochs=epochs, verbose=1)

plot_history(history)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Item (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# User (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# Movie-Embedding (Embedding)     (None, 1, 50)        203100      Item[0][0]
# __________________________________________________________________________________________________
# User-Embedding (Embedding)      (None, 1, 50)        55900       User[0][0]
# __________________________________________________________________________________________________
# FlattenMovies (Flatten)         (None, 50)           0           Movie-Embedding[0][0]
# __________________________________________________________________________________________________
# FlattenUsers (Flatten)          (None, 50)           0           User-Embedding[0][0]
# __________________________________________________________________________________________________
# DotProduct (Dot)                (None, 1)            0           FlattenMovies[0][0]
#                                                                  FlattenUsers[0][0]
# ==================================================================================================
# Total params: 259,000
# Trainable params: 259,000
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/2
# 816591/816591 [==============================] - 76s 93us/step - loss: 0.2020
# Epoch 2/2
#  38240/816591 [>.............................] - ETA: 1:11 - loss: 0.1431

# %%
y_hat = np.round(model.predict([test.name_id, test.bill_id]), 0)
y_true = test.vote

from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_true, y_hat)
# Out:
# 0.23598076

# %%
movie_embedding_learnt = model.get_layer(name='Movie-Embedding').get_weights()[0]
print(movie_embedding_learnt.shape)
user_embedding_learnt = model.get_layer(name='User-Embedding').get_weights()[0]
print(user_embedding_learnt.shape)
pd.DataFrame(movie_embedding_learnt).T.describe()
# Out:
# (4062, 50)
# (1118, 50)
#             0          1          2          3          4          5     \
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean   -0.013081  -0.012483  -0.039562  -0.012608  -0.014548  -0.023833
# std     0.204633   0.210022   0.210527   0.182980   0.204105   0.206236
# min    -0.364699  -0.389722  -0.535761  -0.334602  -0.311115  -0.370457
# 25%    -0.200752  -0.189013  -0.183879  -0.173546  -0.213486  -0.208175
# 50%    -0.018689  -0.012955  -0.048770  -0.026253  -0.013245  -0.030500
# 75%     0.188508   0.193188   0.093123   0.161083   0.167395   0.162443
# max     0.330329   0.317489   0.553695   0.290148   0.406892   0.395596
#
#             6          7          8          9       ...           4052  \
# count  50.000000  50.000000  50.000000  50.000000    ...      50.000000
# mean   -0.004051  -0.019136   0.000529  -0.028546    ...      -0.011394
# std     0.202442   0.188336   0.157369   0.191048    ...       0.208345
# min    -0.397837  -0.328067  -0.504640  -0.375176    ...      -0.399419
# 25%    -0.151518  -0.166425  -0.116012  -0.190194    ...      -0.206098
# 50%    -0.039163  -0.035437   0.025249  -0.049802    ...      -0.028762
# 75%     0.199985   0.163430   0.083597   0.139366    ...       0.168197
# max     0.384108   0.319961   0.265137   0.337620    ...       0.438254
#
#             4053       4054       4055       4056       4057       4058  \
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean   -0.003622  -0.019091  -0.019374  -0.027809  -0.016805  -0.015218
# std     0.205974   0.201746   0.201344   0.198418   0.195514   0.200860
# min    -0.466492  -0.417476  -0.357312  -0.396313  -0.386611  -0.438367
# 25%    -0.136232  -0.150442  -0.188906  -0.207988  -0.161766  -0.190424
# 50%    -0.000882  -0.034359  -0.050553  -0.021368  -0.035403   0.011728
# 75%     0.113639   0.100279   0.153787   0.133066   0.092937   0.106377
# max     0.588809   0.500020   0.312603   0.345952   0.541462   0.355909
#
#             4059       4060       4061
# count  50.000000  50.000000  50.000000
# mean    0.007729   0.004187   0.001143
# std     0.200311   0.185469   0.029331
# min    -0.433690  -0.416236  -0.046388
# 25%    -0.146013  -0.121471  -0.027660
# 50%     0.009019   0.004421   0.004284
# 75%     0.137341   0.121869   0.027195
# max     0.445636   0.472901   0.045515
#
# [8 rows x 4062 columns]

# %%
y = train['party'].values
print(y.shape)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(y)
print(le.classes_)
y = le.transform(y)
print(y)

colors = ['blue', 'red']

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
x_pca = pca.fit_transform(user_embedding_learnt)

plt.figure(1, figsize=(20, 20),)
plt.scatter(x_pca[:, 0], x_pca[:, 1], s=100, c=y, cmap=matplotlib.colors.ListedColormap(colors), alpha=0.6)

# %% [markdown]
# # Non-negative Matrix factorisation (NNMF) in Keras

# %%
from keras.constraints import non_neg

def get_NNMF():
    movie_input = keras.layers.Input(shape=[1],name='Item')
    movie_embedding = keras.layers.Embedding(n_bill + 1, n_latent_factors, 
                                             name='NonNegMovie-Embedding', embeddings_constraint=non_neg())(movie_input)
    movie_vec = keras.layers.Flatten(name='FlattenMovies')(movie_embedding)

    user_input = keras.layers.Input(shape=[1],name='User')
    user_vec = keras.layers.Flatten(name='FlattenUsers')(keras.layers.Embedding(n_users + 1, n_latent_factors,
                                                                                name='NonNegUser-Embedding',embeddings_constraint=non_neg())(user_input))

    prod = keras.layers.dot([movie_vec, user_vec], axes=1,name='DotProduct')
    model = keras.Model([user_input, movie_input], prod)
    model.compile('adam', 'mean_squared_error')
    return model

model = get_NNMF()
print(model.summary())

history_nonneg = model.fit([train.name_id, train.bill_id], 
                           train.vote, epochs=epochs, verbose=1)

plot_history(history_nonneg)

movie_embedding_learnt = model.get_layer(name='NonNegMovie-Embedding').get_weights()[0]
print(movie_embedding_learnt.shape)
# pd.DataFrame(movie_embedding_learnt).describe()

# %% [markdown]
# # Neural networks for recommendation

# %%
n_latent_factors_user = 5
n_latent_factors_movie = 50

def get_nueral_net():
    movie_input = keras.layers.Input(shape=[1],name='Item')
    movie_embedding = keras.layers.Embedding(n_bill + 1, n_latent_factors_movie, name='Movie-Embedding')(movie_input)
    movie_vec = keras.layers.Flatten(name='FlattenMovies')(movie_embedding)
    movie_vec = keras.layers.Dropout(0.2)(movie_vec)


    user_input = keras.layers.Input(shape=[1],name='User')
    user_vec = keras.layers.Flatten(name='FlattenUsers')(keras.layers.Embedding(n_users + 1, n_latent_factors_user,name='User-Embedding')(user_input))
    user_vec = keras.layers.Dropout(0.2)(user_vec)


    concat = keras.layers.concatenate([movie_vec, user_vec], name='Concat')
    concat_dropout = keras.layers.Dropout(0.2)(concat)
    dense = keras.layers.Dense(200,name='FullyConnected')(concat)
    dropout_1 = keras.layers.Dropout(0.2,name='Dropout')(dense)
    dense_2 = keras.layers.Dense(100,name='FullyConnected-1')(concat)
    dropout_2 = keras.layers.Dropout(0.2,name='Dropout')(dense_2)
    dense_3 = keras.layers.Dense(50,name='FullyConnected-2')(dense_2)
    dropout_3 = keras.layers.Dropout(0.2,name='Dropout')(dense_3)
    dense_4 = keras.layers.Dense(20,name='FullyConnected-3', activation='relu')(dense_3)


    result = keras.layers.Dense(1, activation='relu',name='Activation')(dense_4)
    adam = Adam(lr=0.005)
    model = keras.Model([user_input, movie_input], result)
    model.compile(optimizer=adam,loss= 'mean_absolute_error')
#     SVG(model_to_dot(model,  show_shapes=True, show_layer_names=True, rankdir='HB').create(prog='dot', format='svg'))
    return model

# %%
model = get_nueral_net()
model.summary()
history = model.fit([train.name_id, train.bill_id], train.vote, 
                    epochs=epochs, verbose=1)
plot_history(history)

# %%
y_hat_2 = np.round(model.predict([test.name_id, test.bill_id]),0)
print(mean_absolute_error(y_true, y_hat_2))

print(mean_absolute_error(y_true, model.predict([test.name_id, test.bill_id])))

# %%
movie_embedding_learnt = model.get_layer(name='Movie-Embedding').get_weights()[0]
print(movie_embedding_learnt.shape)
