# %%
import xmltodict
from urllib.request import urlopen
import xml.etree.ElementTree as ET
import pandas as pd

from dateutil.parser import parse

import matplotlib.pyplot as plt
from IPython.display import display 

plt.style.use('seaborn-paper')
# %matplotlib inline

# %% [markdown]
# # Hansard - OralQuestionPeriod

# %%
def xml2df(xml_data):
#     print(xml_data)
    root = ET.XML(xml_data) # element tree

    all_records = [] #This is our record list which we will convert into a dataframe
    
    orderOfBusinessList = root.find('HansardBody').iter('OrderOfBusiness')
    
    volume = root.findall(".//ExtractedItem[@Name='Volume']")[0].text
    number = root.findall(".//ExtractedItem[@Name='Number']")[0].text
    session = root.findall(".//ExtractedItem[@Name='Session']")[0].text
    parliament = root.findall(".//ExtractedItem[@Name='Parliament']")[0].text
    speakerName = root.findall(".//ExtractedItem[@Name='SpeakerName']")[0].text
    date = root.findall(".//ExtractedItem[@Name='Date']")[0].text   
#     print(volume)
    
    for orderOfBusiness in orderOfBusinessList:
        
        orderOfBusinessRubric = orderOfBusiness.attrib['Rubric']
#         print('orderOfBusinessRubric', orderOfBusinessRubric)
        if (orderOfBusinessRubric == 'OralQuestionPeriod'):
        
            orderOfBusinessId =  orderOfBusiness.attrib['id']            
            orderOfBusinessCatchLine = orderOfBusiness.find('CatchLine').text
        
            for subjectOfBusiness in orderOfBusiness.findall('SubjectOfBusiness'):

                subjectOfBusinessContent = subjectOfBusiness.find('SubjectOfBusinessContent')
                for intervention in subjectOfBusinessContent.iter('Intervention'):
                    
                    record = {} #Place holder for our record
                    record['orderOfBusinessId'] = orderOfBusinessId
                    record['orderOfBusinessRubric'] = orderOfBusinessRubric
                    record['orderOfBusinessCatchLine'] = orderOfBusinessCatchLine
                    record['volume'] = volume
                    record['number'] = number        
                    record['session'] = session
                    record['parliament'] = parliament
                    record['speakerName'] = speakerName
                    record['date'] = date
                                            
                    try:
                        record['subjectOfBusinessId'] = subjectOfBusiness.attrib['id']
                    except Exception:
                        continue    
                        
                    
                    if subjectOfBusiness.find('SubjectOfBusinessTitle') is not None:
                        record['SubjectOfBusinessTitle'] = subjectOfBusiness.find('SubjectOfBusinessTitle').text.strip()
                    else:
                        record['SubjectOfBusinessTitle'] = 'generic'
                        

                    if subjectOfBusiness.find('FloorLanguage') is not None:
                        record['FloorLanguage'] = subjectOfBusiness.find('FloorLanguage').attrib['language']
                    else:
                        record['FloorLanguage'] = 'EN'

                    record['personSpeaking'] = intervention.findall('PersonSpeaking/Affiliation')[0].text
                    record['personId'] =intervention.findall('PersonSpeaking/Affiliation')[0].attrib['DbId']
                    
                    # Get all texts from intervention - Only one person is speaking per intervention.
#                     content = []
                    
                    content = ET.tostring(intervention.find('Content'), encoding='UTF-8', method='text')
                    record['content'] = content.decode('UTF-8')
#                     for paraText in intervention.iter('ParaText'):
#                         if paraText.text is not None:
#                             content.append(paraText.text)

#                     record['content'] = ' \lineBreak '.join(content)
                    
                    all_records.append(record) #Append this record to all_records. 

    return pd.DataFrame(all_records) #return records as DataFrame

# %%
link = 'http://www.ourcommons.ca/Content/House/{parliamentSession}/Debates/{session}/HAN{session}-E.XML'
# link = 'http://www.ourcommons.ca/Content/House/412/Debates/{session}/HAN{session}-E.XML'

link_list = []
session = 10
# session = 236
# session = 264
parliament_session  = {'421' : 265,
                       '412' : 235,
                       '411': 272}

# parliament_session  = {'421' : 10,
#                        '412' : 10,
#                        '411': 210}

for parliament, session  in parliament_session.items():
    print(parliament, session)
    for i in range (1, session + 1):
        temp = link.replace('{parliamentSession}', parliament)
        temp = temp.replace('{session}', '{:03}'.format(i))
        link_list.append(temp)

print('link_list', len(link_list))
print(link_list[1])
# Out:
# 421 265
# 412 235
# 411 272
# link_list 772
# http://www.ourcommons.ca/Content/House/421/Debates/002/HAN002-E.XML

# %%
from joblib import Parallel, delayed
import multiprocessing
    
df_list = []
def processLink(link):
    print('processing', link)
    urlContent = urlopen(link)
    xml = urlContent.read()
    return xml2df(xml)

num_cores = multiprocessing.cpu_count()
print(num_cores)
    
results = Parallel(n_jobs=num_cores)(delayed(processLink)(i) for i in link_list)
# Out:
# 8
# processing http://www.ourcommons.ca/Content/House/421/Debates/003/HAN003-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/005/HAN005-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/004/HAN004-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/007/HAN007-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/008/HAN008-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/006/HAN006-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/002/HAN002-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/001/HAN001-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/009/HAN009-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/010/HAN010-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/011/HAN011-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/012/HAN012-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/013/HAN013-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/014/HAN014-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/015/HAN015-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/016/HAN016-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/017/HAN017-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/018/HAN018-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/019/HAN019-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/020/HAN020-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/021/HAN021-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/022/HAN022-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/023/HAN023-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/024/HAN024-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/025/HAN025-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/026/HAN026-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/027/HAN027-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/028/HAN028-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/029/HAN029-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/030/HAN030-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/031/HAN031-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/032/HAN032-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/033/HAN033-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/034/HAN034-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/035/HAN035-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/036/HAN036-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/037/HAN037-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/038/HAN038-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/039/HAN039-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/040/HAN040-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/041/HAN041-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/042/HAN042-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/043/HAN043-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/044/HAN044-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/045/HAN045-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/046/HAN046-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/047/HAN047-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/048/HAN048-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/049/HAN049-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/050/HAN050-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/051/HAN051-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/052/HAN052-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/053/HAN053-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/054/HAN054-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/055/HAN055-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/056/HAN056-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/057/HAN057-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/058/HAN058-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/059/HAN059-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/060/HAN060-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/061/HAN061-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/062/HAN062-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/063/HAN063-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/064/HAN064-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/065/HAN065-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/066/HAN066-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/067/HAN067-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/068/HAN068-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/069/HAN069-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/070/HAN070-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/071/HAN071-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/072/HAN072-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/073/HAN073-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/074/HAN074-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/075/HAN075-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/076/HAN076-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/077/HAN077-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/078/HAN078-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/079/HAN079-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/080/HAN080-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/081/HAN081-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/082/HAN082-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/083/HAN083-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/084/HAN084-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/085/HAN085-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/086/HAN086-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/087/HAN087-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/088/HAN088-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/089/HAN089-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/090/HAN090-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/091/HAN091-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/092/HAN092-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/093/HAN093-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/094/HAN094-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/095/HAN095-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/096/HAN096-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/097/HAN097-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/098/HAN098-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/099/HAN099-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/100/HAN100-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/101/HAN101-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/102/HAN102-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/103/HAN103-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/104/HAN104-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/105/HAN105-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/106/HAN106-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/107/HAN107-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/108/HAN108-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/109/HAN109-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/110/HAN110-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/111/HAN111-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/112/HAN112-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/113/HAN113-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/114/HAN114-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/115/HAN115-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/116/HAN116-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/117/HAN117-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/118/HAN118-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/119/HAN119-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/120/HAN120-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/121/HAN121-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/122/HAN122-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/123/HAN123-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/124/HAN124-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/125/HAN125-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/126/HAN126-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/127/HAN127-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/128/HAN128-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/129/HAN129-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/130/HAN130-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/131/HAN131-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/132/HAN132-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/133/HAN133-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/134/HAN134-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/135/HAN135-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/136/HAN136-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/137/HAN137-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/138/HAN138-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/139/HAN139-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/140/HAN140-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/141/HAN141-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/142/HAN142-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/143/HAN143-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/144/HAN144-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/145/HAN145-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/146/HAN146-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/147/HAN147-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/148/HAN148-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/149/HAN149-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/150/HAN150-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/151/HAN151-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/152/HAN152-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/153/HAN153-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/154/HAN154-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/155/HAN155-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/156/HAN156-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/157/HAN157-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/158/HAN158-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/159/HAN159-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/160/HAN160-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/161/HAN161-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/162/HAN162-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/163/HAN163-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/164/HAN164-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/165/HAN165-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/166/HAN166-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/167/HAN167-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/168/HAN168-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/169/HAN169-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/170/HAN170-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/171/HAN171-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/172/HAN172-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/173/HAN173-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/174/HAN174-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/176/HAN176-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/175/HAN175-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/177/HAN177-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/178/HAN178-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/179/HAN179-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/180/HAN180-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/181/HAN181-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/182/HAN182-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/183/HAN183-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/184/HAN184-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/185/HAN185-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/186/HAN186-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/187/HAN187-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/188/HAN188-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/189/HAN189-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/190/HAN190-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/191/HAN191-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/192/HAN192-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/193/HAN193-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/194/HAN194-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/195/HAN195-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/196/HAN196-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/197/HAN197-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/198/HAN198-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/199/HAN199-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/200/HAN200-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/201/HAN201-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/202/HAN202-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/203/HAN203-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/204/HAN204-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/205/HAN205-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/206/HAN206-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/207/HAN207-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/208/HAN208-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/209/HAN209-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/210/HAN210-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/211/HAN211-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/212/HAN212-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/213/HAN213-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/214/HAN214-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/215/HAN215-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/216/HAN216-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/217/HAN217-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/218/HAN218-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/219/HAN219-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/220/HAN220-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/221/HAN221-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/222/HAN222-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/223/HAN223-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/224/HAN224-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/225/HAN225-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/226/HAN226-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/227/HAN227-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/228/HAN228-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/229/HAN229-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/230/HAN230-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/231/HAN231-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/232/HAN232-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/233/HAN233-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/234/HAN234-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/235/HAN235-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/236/HAN236-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/237/HAN237-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/238/HAN238-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/239/HAN239-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/240/HAN240-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/241/HAN241-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/242/HAN242-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/243/HAN243-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/244/HAN244-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/245/HAN245-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/246/HAN246-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/247/HAN247-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/248/HAN248-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/249/HAN249-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/250/HAN250-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/251/HAN251-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/252/HAN252-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/253/HAN253-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/254/HAN254-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/255/HAN255-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/256/HAN256-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/257/HAN257-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/258/HAN258-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/259/HAN259-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/260/HAN260-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/261/HAN261-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/262/HAN262-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/263/HAN263-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/264/HAN264-E.XML
# processing http://www.ourcommons.ca/Content/House/421/Debates/265/HAN265-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/001/HAN001-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/002/HAN002-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/003/HAN003-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/004/HAN004-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/005/HAN005-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/006/HAN006-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/007/HAN007-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/008/HAN008-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/009/HAN009-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/010/HAN010-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/011/HAN011-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/012/HAN012-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/013/HAN013-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/014/HAN014-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/015/HAN015-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/016/HAN016-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/017/HAN017-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/018/HAN018-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/019/HAN019-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/020/HAN020-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/021/HAN021-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/022/HAN022-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/023/HAN023-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/024/HAN024-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/025/HAN025-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/026/HAN026-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/027/HAN027-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/028/HAN028-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/029/HAN029-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/030/HAN030-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/031/HAN031-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/032/HAN032-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/033/HAN033-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/034/HAN034-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/035/HAN035-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/036/HAN036-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/037/HAN037-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/038/HAN038-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/039/HAN039-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/040/HAN040-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/041/HAN041-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/042/HAN042-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/043/HAN043-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/044/HAN044-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/045/HAN045-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/046/HAN046-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/047/HAN047-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/048/HAN048-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/049/HAN049-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/050/HAN050-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/051/HAN051-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/052/HAN052-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/053/HAN053-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/054/HAN054-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/055/HAN055-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/056/HAN056-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/057/HAN057-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/058/HAN058-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/059/HAN059-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/060/HAN060-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/061/HAN061-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/062/HAN062-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/063/HAN063-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/064/HAN064-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/065/HAN065-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/066/HAN066-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/067/HAN067-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/068/HAN068-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/069/HAN069-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/070/HAN070-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/071/HAN071-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/072/HAN072-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/073/HAN073-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/074/HAN074-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/075/HAN075-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/076/HAN076-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/077/HAN077-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/078/HAN078-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/079/HAN079-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/080/HAN080-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/081/HAN081-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/082/HAN082-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/083/HAN083-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/084/HAN084-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/085/HAN085-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/086/HAN086-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/087/HAN087-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/088/HAN088-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/089/HAN089-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/090/HAN090-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/091/HAN091-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/092/HAN092-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/093/HAN093-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/094/HAN094-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/095/HAN095-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/096/HAN096-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/097/HAN097-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/098/HAN098-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/099/HAN099-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/100/HAN100-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/101/HAN101-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/102/HAN102-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/103/HAN103-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/104/HAN104-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/105/HAN105-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/106/HAN106-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/107/HAN107-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/108/HAN108-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/109/HAN109-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/110/HAN110-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/111/HAN111-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/112/HAN112-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/113/HAN113-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/114/HAN114-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/115/HAN115-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/116/HAN116-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/117/HAN117-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/118/HAN118-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/119/HAN119-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/120/HAN120-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/121/HAN121-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/122/HAN122-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/123/HAN123-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/124/HAN124-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/125/HAN125-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/126/HAN126-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/127/HAN127-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/128/HAN128-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/129/HAN129-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/130/HAN130-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/131/HAN131-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/132/HAN132-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/133/HAN133-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/134/HAN134-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/135/HAN135-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/136/HAN136-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/137/HAN137-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/138/HAN138-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/139/HAN139-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/140/HAN140-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/141/HAN141-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/142/HAN142-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/143/HAN143-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/144/HAN144-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/145/HAN145-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/146/HAN146-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/147/HAN147-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/148/HAN148-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/149/HAN149-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/150/HAN150-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/151/HAN151-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/152/HAN152-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/153/HAN153-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/154/HAN154-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/155/HAN155-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/156/HAN156-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/157/HAN157-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/158/HAN158-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/159/HAN159-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/160/HAN160-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/161/HAN161-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/162/HAN162-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/163/HAN163-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/164/HAN164-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/165/HAN165-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/166/HAN166-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/167/HAN167-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/168/HAN168-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/169/HAN169-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/170/HAN170-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/171/HAN171-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/172/HAN172-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/173/HAN173-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/174/HAN174-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/175/HAN175-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/176/HAN176-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/177/HAN177-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/178/HAN178-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/179/HAN179-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/180/HAN180-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/181/HAN181-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/182/HAN182-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/183/HAN183-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/184/HAN184-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/185/HAN185-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/186/HAN186-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/187/HAN187-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/188/HAN188-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/189/HAN189-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/190/HAN190-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/191/HAN191-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/192/HAN192-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/193/HAN193-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/194/HAN194-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/195/HAN195-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/196/HAN196-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/197/HAN197-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/198/HAN198-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/199/HAN199-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/200/HAN200-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/201/HAN201-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/202/HAN202-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/203/HAN203-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/204/HAN204-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/205/HAN205-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/206/HAN206-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/207/HAN207-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/208/HAN208-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/209/HAN209-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/210/HAN210-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/211/HAN211-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/212/HAN212-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/213/HAN213-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/214/HAN214-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/215/HAN215-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/216/HAN216-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/217/HAN217-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/218/HAN218-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/219/HAN219-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/220/HAN220-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/221/HAN221-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/222/HAN222-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/223/HAN223-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/224/HAN224-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/225/HAN225-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/226/HAN226-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/227/HAN227-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/228/HAN228-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/229/HAN229-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/230/HAN230-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/231/HAN231-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/232/HAN232-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/233/HAN233-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/234/HAN234-E.XML
# processing http://www.ourcommons.ca/Content/House/412/Debates/235/HAN235-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/001/HAN001-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/002/HAN002-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/003/HAN003-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/004/HAN004-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/005/HAN005-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/006/HAN006-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/007/HAN007-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/008/HAN008-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/009/HAN009-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/010/HAN010-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/011/HAN011-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/012/HAN012-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/013/HAN013-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/014/HAN014-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/015/HAN015-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/016/HAN016-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/017/HAN017-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/018/HAN018-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/019/HAN019-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/020/HAN020-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/021/HAN021-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/022/HAN022-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/023/HAN023-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/024/HAN024-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/025/HAN025-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/026/HAN026-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/027/HAN027-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/028/HAN028-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/029/HAN029-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/030/HAN030-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/031/HAN031-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/032/HAN032-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/033/HAN033-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/034/HAN034-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/035/HAN035-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/036/HAN036-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/037/HAN037-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/038/HAN038-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/039/HAN039-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/040/HAN040-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/041/HAN041-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/042/HAN042-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/043/HAN043-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/044/HAN044-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/045/HAN045-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/046/HAN046-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/047/HAN047-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/048/HAN048-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/049/HAN049-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/050/HAN050-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/051/HAN051-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/052/HAN052-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/053/HAN053-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/054/HAN054-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/055/HAN055-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/056/HAN056-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/057/HAN057-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/058/HAN058-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/059/HAN059-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/060/HAN060-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/061/HAN061-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/062/HAN062-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/063/HAN063-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/064/HAN064-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/065/HAN065-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/066/HAN066-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/067/HAN067-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/068/HAN068-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/069/HAN069-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/070/HAN070-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/071/HAN071-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/072/HAN072-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/073/HAN073-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/074/HAN074-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/075/HAN075-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/076/HAN076-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/077/HAN077-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/078/HAN078-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/079/HAN079-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/080/HAN080-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/081/HAN081-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/082/HAN082-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/083/HAN083-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/084/HAN084-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/085/HAN085-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/086/HAN086-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/087/HAN087-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/088/HAN088-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/089/HAN089-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/090/HAN090-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/091/HAN091-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/092/HAN092-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/093/HAN093-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/094/HAN094-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/095/HAN095-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/096/HAN096-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/097/HAN097-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/098/HAN098-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/099/HAN099-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/100/HAN100-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/101/HAN101-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/102/HAN102-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/103/HAN103-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/104/HAN104-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/105/HAN105-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/106/HAN106-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/107/HAN107-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/108/HAN108-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/109/HAN109-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/110/HAN110-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/111/HAN111-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/112/HAN112-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/113/HAN113-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/114/HAN114-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/115/HAN115-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/116/HAN116-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/117/HAN117-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/118/HAN118-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/119/HAN119-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/120/HAN120-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/121/HAN121-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/122/HAN122-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/123/HAN123-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/124/HAN124-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/125/HAN125-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/126/HAN126-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/127/HAN127-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/128/HAN128-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/129/HAN129-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/130/HAN130-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/131/HAN131-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/132/HAN132-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/133/HAN133-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/134/HAN134-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/135/HAN135-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/136/HAN136-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/137/HAN137-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/138/HAN138-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/139/HAN139-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/140/HAN140-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/141/HAN141-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/142/HAN142-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/143/HAN143-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/144/HAN144-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/145/HAN145-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/146/HAN146-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/147/HAN147-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/149/HAN149-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/148/HAN148-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/150/HAN150-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/151/HAN151-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/152/HAN152-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/153/HAN153-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/154/HAN154-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/155/HAN155-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/156/HAN156-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/157/HAN157-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/158/HAN158-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/159/HAN159-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/160/HAN160-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/161/HAN161-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/162/HAN162-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/163/HAN163-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/164/HAN164-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/165/HAN165-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/166/HAN166-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/167/HAN167-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/168/HAN168-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/169/HAN169-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/170/HAN170-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/171/HAN171-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/172/HAN172-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/173/HAN173-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/174/HAN174-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/175/HAN175-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/176/HAN176-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/177/HAN177-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/178/HAN178-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/179/HAN179-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/180/HAN180-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/181/HAN181-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/182/HAN182-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/183/HAN183-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/184/HAN184-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/185/HAN185-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/186/HAN186-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/187/HAN187-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/188/HAN188-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/189/HAN189-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/190/HAN190-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/191/HAN191-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/192/HAN192-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/193/HAN193-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/194/HAN194-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/195/HAN195-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/196/HAN196-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/197/HAN197-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/198/HAN198-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/199/HAN199-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/200/HAN200-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/201/HAN201-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/202/HAN202-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/203/HAN203-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/204/HAN204-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/205/HAN205-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/206/HAN206-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/207/HAN207-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/208/HAN208-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/209/HAN209-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/210/HAN210-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/211/HAN211-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/212/HAN212-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/213/HAN213-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/214/HAN214-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/215/HAN215-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/216/HAN216-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/217/HAN217-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/218/HAN218-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/219/HAN219-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/220/HAN220-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/221/HAN221-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/222/HAN222-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/223/HAN223-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/224/HAN224-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/225/HAN225-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/226/HAN226-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/227/HAN227-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/228/HAN228-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/229/HAN229-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/230/HAN230-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/231/HAN231-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/232/HAN232-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/233/HAN233-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/234/HAN234-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/235/HAN235-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/236/HAN236-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/237/HAN237-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/238/HAN238-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/239/HAN239-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/240/HAN240-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/241/HAN241-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/242/HAN242-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/243/HAN243-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/244/HAN244-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/245/HAN245-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/246/HAN246-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/247/HAN247-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/248/HAN248-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/249/HAN249-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/250/HAN250-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/251/HAN251-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/252/HAN252-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/253/HAN253-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/254/HAN254-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/255/HAN255-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/256/HAN256-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/257/HAN257-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/258/HAN258-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/259/HAN259-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/260/HAN260-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/261/HAN261-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/262/HAN262-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/263/HAN263-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/264/HAN264-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/265/HAN265-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/266/HAN266-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/267/HAN267-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/268/HAN268-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/269/HAN269-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/270/HAN270-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/271/HAN271-E.XML
# processing http://www.ourcommons.ca/Content/House/411/Debates/272/HAN272-E.XML

# %%
# results[0]

df_hansard = pd.concat(results)
df_hansard.reset_index(inplace=True)

df_hansard['date'] =  pd.to_datetime(df_hansard['date'])

df_hansard.to_csv('data/hansard_all.csv')
df_hansard.tail()
# Out:
#        index FloorLanguage SubjectOfBusinessTitle  \
# 69663     80            EN             Employment
# 69664     81            EN        Points of Order
# 69665     82            EN        Points of Order
# 69666     83            EN        Points of Order
# 69667     84            EN        Points of Order
#
#                                                  content       date  \
# 69663  Mr. Speaker, our government has introduced ref... 2013-06-18
# 69664  Mr. Speaker, I raised this point of order some... 2013-06-18
# 69665  I thank the hon. member for Saanich—Gulf Islan... 2013-06-18
# 69666  Mr. Speaker, I heard the comment from the memb... 2013-06-18
# 69667  We are certainly not going to get into debate ... 2013-06-18
#
#            number orderOfBusinessCatchLine orderOfBusinessId  \
# 69663  NUMBER 272           Oral Questions           8090062
# 69664  NUMBER 272           Oral Questions           8090062
# 69665  NUMBER 272           Oral Questions           8090062
# 69666  NUMBER 272           Oral Questions           8090062
# 69667  NUMBER 272           Oral Questions           8090062
#
#       orderOfBusinessRubric       parliament personId  \
# 69663    OralQuestionPeriod  41st PARLIAMENT   170869
# 69664    OralQuestionPeriod  41st PARLIAMENT   170542
# 69665    OralQuestionPeriod  41st PARLIAMENT   170958
# 69666    OralQuestionPeriod  41st PARLIAMENT   170302
# 69667    OralQuestionPeriod  41st PARLIAMENT   170958
#
#                                           personSpeaking      session  \
# 69663  Ms. Kellie Leitch (Parliamentary Secretary to ...  1st SESSION
# 69664       Ms. Elizabeth May (Saanich—Gulf Islands, GP)  1st SESSION
# 69665                                        The Speaker  1st SESSION
# 69666      Mr. Daryl Kramp (Prince Edward—Hastings, CPC)  1st SESSION
# 69667                                        The Speaker  1st SESSION
#
#                                  speakerName subjectOfBusinessId      volume
# 69663  Speaker: The Honourable Andrew Scheer             8090323  VOLUME 146
# 69664  Speaker: The Honourable Andrew Scheer             8090331  VOLUME 146
# 69665  Speaker: The Honourable Andrew Scheer             8090331  VOLUME 146
# 69666  Speaker: The Honourable Andrew Scheer             8090331  VOLUME 146
# 69667  Speaker: The Honourable Andrew Scheer             8090331  VOLUME 146

# %%
df_hansard['content'][0]
# Out:
# b'Mr. Speaker, an astonishing 600 aboriginal women have been murdered or reported missing across Canada. The National Chief of the Assembly of First Nations, Shawn Atleo, has called for a national inquiry. The UN rapporteur has called for a national inquiry.If, in a city the size of Ottawa, 600 women were murdered or missing, there would not have to be protests in the streets to get a national inquiry; one would have been called a very long time ago. Why is the Prime Minister still refusing to hold a national inquiry into the national tragedy of 600 murdered and missing aboriginal women?'

# %%
print(df_hansard['SubjectOfBusinessTitle'].value_counts()[:50])

df_hansard['SubjectOfBusinessTitle'].value_counts()[:50].plot(kind='bar', alpha=.5, figsize=(12,6), fontsize=14)
# Out:
# Ethics                                   7074
# National Defence                         3745
# Taxation                                 3018
# The Environment                          2761
# Foreign Affairs                          2100
# Public Safety                            2043
# Employment                               1975
# Democratic Reform                        1675
# Health                                   1656
# Aboriginal Affairs                       1566
# Employment Insurance                     1531
# International Trade                      1475
# Veterans Affairs                         1369
# Justice                                  1362
# Natural Resources                        1343
# Infrastructure                           1330
# The Economy                              1297
# Citizenship and Immigration              1147
# Points of Order                           977
# generic                                   907
# Indigenous Affairs                        876
# Pensions                                  863
# Government Appointments                   824
# The Budget                                802
# 41st General Election                     730
# Finance                                   727
# Foreign Investment                        677
# Fisheries and Oceans                      677
# Rail Transportation                       628
# Immigration, Refugees and Citizenship     601
# Canada Revenue Agency                     585
# Business of Supply                        541
# Agriculture and Agri-Food                 531
# Canadian Heritage                         495
# Business of the House                     440
# Status of Women                           428
# Canada Post                               417
# Privilege                                 406
# Food Safety                               402
# Search and Rescue                         397
# Housing                                   397
# Presence in Gallery                       381
# Privacy                                   376
# Public Services and Procurement           354
# Official Languages                        332
# Softwood Lumber                           307
# Government Expenditures                   297
# International Development                 292
# Intergovernmental Relations               280
# Consumer Protection                       279
# Name: SubjectOfBusinessTitle, dtype: int64

# %%
# https://www.ourcommons.ca/en/open-data#ChamberDebates
link =  'http://www.ourcommons.ca/Content/House/{ParliamentSession}/Debates/{SittingNumber}/HAN{SittingNumber}-E.XML'

# https://www.ourcommons.ca/Content/House/421/Debates/251/HAN251-E.XML
    
link = link.replace('{ParliamentSession}', '421')
link = link.replace('{SittingNumber}', '251')
link = link.replace('{SittingNumber}', '251')

print(link)


def xml2df(xml_data):
#     print(xml_data)
    root = ET.XML(xml_data) # element tree

    all_records = [] #This is our record list which we will convert into a dataframe
    
    orderOfBusinessList = root.find('HansardBody').iter('OrderOfBusiness')
    
    
    for orderOfBusiness in orderOfBusinessList:
        
#         print(orderOfBusiness.find('CatchLine'))
        orderOfBusinessId =  orderOfBusiness.attrib['id']
        orderOfBusinessRubric = orderOfBusiness.attrib['Rubric']
        orderOfBusinessCatchLine = orderOfBusiness.find('CatchLine').text
#         orderOfBusinessFloorLanguage = orderOfBusiness.find('SubjectOfBusiness')
        
#         record['timestamp'] = parse( publicationItem.attrib['Date'])
#         record['speakerId'] = publicationItem.find('Person').attrib['Id']
        paragraphs = []
        for subjectOfBusiness in orderOfBusiness.findall('SubjectOfBusiness'):
            record = {} #Place holder for our record
#             print(subjectOfBusiness.attrib)
            try:
                record['subjectOfBusinessId'] = subjectOfBusiness.attrib['id']
            except Exception:
                continue
                
            record['orderOfBusinessId'] = orderOfBusinessId
            record['orderOfBusinessRubric'] = orderOfBusinessRubric
            record['orderOfBusinessCatchLine'] = orderOfBusinessCatchLine
            
            if subjectOfBusiness.find('SubjectOfBusinessTitle') is not None:
                record['SubjectOfBusinessTitle'] = subjectOfBusiness.find('SubjectOfBusinessTitle').text
            else:
                record['SubjectOfBusinessTitle'] = 'generic'
            
            if subjectOfBusiness.find('FloorLanguage') is not None:
                record['FloorLanguage'] = subjectOfBusiness.find('FloorLanguage').attrib['language']
            else:
                record['FloorLanguage'] = 'EN'
               
#           print(subjectOfBusiness.findall("Intervention/PersonSpeaking/Affiliation"))
            # SpeakerId
#             if subjectOfBusiness.findall("./Intervention/PersonSpeaking/Affiliation") is not None:
#                 record['speakerId'] = subjectOfBusiness.findall("./Intervention/PersonSpeaking/Affiliation")[0].attrib['DbId']
#             else:
#                 record['speakerId'] = '1' # generic
                
                
                
            subjectOfBusinessContent = subjectOfBusiness.find('SubjectOfBusinessContent')
            
#             print(subjectOfBusinessContent.iter('ParaText'))
            content = []
            
            for paraText in subjectOfBusinessContent.iter('ParaText'):
                content.append(paraText.text)
                
            record['content'] = content
            
            all_records.append(record) #Append this record to all_records. 
            
#         record['paragText'] = paragraphs        
#         break
    
    df = pd.DataFrame(all_records)
    df.set_index(df['subjectOfBusinessId'])
    return df #return records as DataFrame

# Id	paragText	speakerId	timestamp

urlContent = urlopen(link)
xml = urlContent.read()
df = xml2df(xml)

# df['content'][2]

df.head()
# df.tail()
# df.info()

# %%
# for row in df['content'].values:
#     print(row)

# df

# %%
link = 'http://www.ourcommons.ca/Parliamentarians/en/PublicationSearch?View=D&Item=&ParlSes=42-1&oob=&Topic=&Per=&Prov=&Cauc=&Text=&RPP=15&order=&targetLang=&SBS=0&MRR=150000&PubType=37&xml=1'
#        'http://www.ourcommons.ca/Parliamentarians/en/PublicationSearch?View=L&Item=&ParlSes=42-1&Topic=38047&com=&Per=&Prov=&Cauc=&PartType=&Text=&RPP=15&order=&targetLang=&SBS=0&MRR=2000000&PubType=40017&xml=1'
urlContent = urlopen(link)
xml = urlContent.read()
print(xml)

# %%
# print(len(doc['Results']))

# print(doc['Results']['Publications']['Publication'][0]['PublicationItems']['PublicationItem'][0]
#       ['XmlContent']['Intervention']['Content']['ParaText'][1])



# <PublicationItem Id="9326459" EventId="9885804" 
# VideoURL="" Sequence="5" Page="16240" PdfPage="4" 
# TypeId="38" Date="2017-12-11" Hour="11" Minute="12" Second="20" 
# FacebookLink="?PubType=37&Item=9326459" TwitterLink="">
from datetime import datetime




def xml2df(xml_data):
#     print(xml_data)
    root = ET.XML(xml_data) # element tree

    all_records = [] #This is our record list which we will convert into a dataframe
    
    for publicationItem in root.iter('PublicationItem'):
        record = {} #Place holder for our record
        record['Id'] =  publicationItem.attrib['Id']
        record['timestamp'] = parse( publicationItem.attrib['Date'])
        record['speakerId'] = publicationItem.find('Person').attrib['Id']
        paragraphs = []
        for paratext in publicationItem.find('XmlContent').iter('ParaText'):
            paragraphs.append(paratext.text)
            
        record['paragText'] = paragraphs

        
    
        all_records.append(record) #Append this record to all_records. 
#         break
    
    df = pd.DataFrame(all_records)
    df.set_index(df['Id'])
    return df #return records as DataFrame

# print(urlContent.read())
df = xml2df(xml)

df.to_csv('results.csv' , sep='\t', encoding='utf-8')

# df
# df.describe()


# for item in doc['Results']['Publications']['Publication'][0]
# ['PublicationItems']['PublicationItem']:
# #     print(item['XmlContent']['Intervention']['Content']['ParaText'])
# #     for key in item.keys():
# #         print(key, item[key])
        

#     break
